# %% [markdown]
# <div style="background: linear-gradient(135deg, #0f0c29, #302b63, #24243e); border-radius: 16px; padding: 36px 40px; margin-bottom: 8px;">
#   <h1 style="color: #e0aaff; font-size: 2.4em; font-weight: 800; margin: 0 0 10px 0; letter-spacing: 1px;">
#     ⚡ RealMLP · Health Condition Classification
#   </h1>
#   <p style="color: #c77dff; font-size: 1.15em; margin: 0 0 18px 0; font-weight: 500;">
#     Playground Series · Season 6 Episode 7
#   </p>
#   <hr style="border: none; border-top: 1px solid #7b2d8b; margin: 16px 0;">
#   <p style="color: #9d8cff; font-size: 0.97em; margin: 0;">
#     Built directly on the top public RealMLP baseline — keeping every single logical decision
#     exactly as-is, extended only with unique feature additions:
#     <strong> Nonlinear transforms</strong>, <strong>physically meaningful features</strong>,
#     <strong>categorical pair interactions</strong>, and <strong>stress-level aggregations</strong>.
#     Full credit for the core architecture and FE design belongs to the original author. 🫡
#   </p>
# </div>

# %% [markdown]
# <div style="background: linear-gradient(90deg, #10002b, #240046); border-left: 4px solid #c77dff; border-radius: 8px; padding: 18px 24px;">
#   <h2 style="color: #e0aaff; margin: 0 0 8px 0;">📦 Setup & Imports</h2>
#   <p style="color: #9d8cff; margin: 0;">PyTorch · sklearn · scipy. Seed 63 everywhere.</p>
# </div>

# %% [markdown]
# <div style="background: linear-gradient(90deg, #03071e, #370617); border-left: 4px solid #f48c06; border-radius: 8px; padding: 18px 24px;">
#   <h2 style="color: #ffd60a; margin: 0 0 8px 0;">📡 Load Data</h2>
#   <p style="color: #ffb703; margin: 0;">Competition train + test. Labels mapped to integers.</p>
# </div>

# %% [markdown]
# <div style="background: linear-gradient(90deg, #012a4a, #013a63); border-left: 4px solid #48cae4; border-radius: 8px; padding: 18px 24px;">
#   <h2 style="color: #90e0ef; margin: 0 0 10px 0;">🔬 Feature Engineering</h2>
#   <p style="color: #ade8f4; margin: 0 0 8px 0;">Everything from the top public baseline <strong>exactly as-is</strong>, plus these unique additions:</p>
#   <ul style="color: #caf0f8; margin: 0; padding-left: 20px;">
#     <li><strong>water_intake_cat2_</strong> — extra fine bin (×50) for water intake</li>
#     <li><strong>Logical nonlinear features</strong> — sin/sigmoid/log1p/tanh/cube transforms discovered via genetic programming</li>
#     <li><strong>Ratio features</strong> — 8 cross-column physically meaningful ratios (pace, intensity, efficiency)</li>
#     <li><strong>Pair combo cats</strong> — 10 stress/activity/sleep/diet categorical interactions</li>
#     <li><strong>Stress-agg medians</strong> — per-fold median of 5 key numerics grouped by stress_level</li>
#   </ul>
# </div>

# %% [markdown]
# <div style="background: linear-gradient(90deg, #1b1b2f, #2d2b55); border-left: 4px solid #a855f7; border-radius: 8px; padding: 18px 24px;">
#   <h2 style="color: #d8b4fe; margin: 0 0 10px 0;">🧠 Model Components — RealMLP</h2>
#   <ul style="color: #c4b5fd; margin: 0; padding-left: 20px;">
#     <li><strong>PBLD</strong> — periodic basis with learned decay (PReLU) for numericals</li>
#     <li><strong>NTPLinear</strong> — normalized ensemble linear projections</li>
#     <li><strong>EMA</strong> — exponential moving average of weights for stable validation</li>
#     <li><strong>ScalingLayer + flat_cos schedule</strong> — exact public baseline config</li>
#   </ul>
# </div>

# %% [markdown]
# <div style="background: linear-gradient(90deg, #0d1b2a, #1b263b); border-left: 4px solid #00b4d8; border-radius: 8px; padding: 18px 24px;">
#   <h2 style="color: #90e0ef; margin: 0 0 8px 0;">⚙️ Schedules · Parameter Groups · Loss · Classifier</h2>
#   <p style="color: #ade8f4; margin: 0;">Exact same logic as the public baseline. Zero changes.</p>
# </div>

# %% [markdown]
# <div style="background: linear-gradient(90deg, #1a1a2e, #16213e); border-left: 4px solid #e94560; border-radius: 8px; padding: 18px 24px;">
#   <h2 style="color: #f5a623; margin: 0 0 8px 0;">🎛️ Config — Exact Public Baseline</h2>
#   <p style="color: #ffd6a5; margin: 0;">Not a single value changed. Seed 63, 7 folds.</p>
# </div>

# %% [markdown]
# <div style="background: linear-gradient(135deg, #0f3460, #16213e, #1a1a2e); border-left: 4px solid #0f3460; border-radius: 8px; padding: 18px 24px; border: 1px solid #533483;">
#   <h2 style="color: #e94560; margin: 0 0 10px 0;">🚀 7-Fold Cross Validation</h2>
#   <ul style="color: #a8dadc; margin: 0; padding-left: 20px;">
#     <li>Target encoding on all non-bin cat cols — per fold, no leakage</li>
#     <li>Stress-agg medians computed per fold on train only — no leakage</li>
#     <li>Same StratifiedKFold split logic as public baseline</li>
#   </ul>
# </div>

# %% [markdown]
# <div style="background: linear-gradient(90deg, #2d0036, #4a0060); border-left: 4px solid #bf5af2; border-radius: 8px; padding: 18px 24px;">
#   <h2 style="color: #e0aaff; margin: 0 0 8px 0;">💾 Save Outputs</h2>
#   <p style="color: #c77dff; margin: 0;"><strong>oof_preds.csv</strong> · <strong>test_preds.csv</strong> · <strong>submission.csv</strong> (calibrated)</p>
# </div>
